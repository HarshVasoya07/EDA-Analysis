# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random

# %%
'''Question 1: Does 'Display' have more impact on demand than 'feature' or its the other way around?
answer: Based on what i understood about EDA and watching the previous couple of videos both Display and Feature 
increases sales when promoted via display and featured. Based on the EDA it is favoring feature and when items are
featured the sales increases. we can not conclude the answer becuase both of the stratagies help business grow in 
demand when either products are displayed or featured. SO either way product increased in sales by looking at 
graphs in EDA. 10% on featured and 13% displayed so slightly better sales for displayed.

Question 2: Does the number of unique Manufacturers for category & subcategory impact on the demand?
Answer: Based on my understanding unique manufacturers do not affect the impact on the sales it is purely based on
price, promotionals for products and the need for customers. for example as mentioned in the EDA boxed Pizza 
Manufacturers with higher products price had better sales than cheaper boxed pizza. Similarly, hygine products with
lower prices has better sales than expensive once.

# %%
#question 3 hypothesis.

train = pd.read_csv('Downloads/EDADatasetsNotebooks-191218-192739/EDA Datasets & Notebooks/train.csv')
product_data = pd.read_csv('Downloads/EDADatasetsNotebooks-191218-192739/EDA Datasets & Notebooks/product_data.csv')
store_data = pd.read_csv('Downloads/EDADatasetsNotebooks-191218-192739/EDA Datasets & Notebooks/store_data.csv')

# %%
train.head()
# Out:
#   WEEK_END_DATE  STORE_NUM         UPC  PRICE  BASE_PRICE  FEATURE  DISPLAY  \
# 0     14-Jan-09        367  1111009477   1.39        1.57        0        0
# 1     14-Jan-09        367  1111009497   1.39        1.39        0        0
# 2     14-Jan-09        367  1111085319   1.88        1.88        0        0
# 3     14-Jan-09        367  1111085345   1.88        1.88        0        0
# 4     14-Jan-09        367  1111085350   1.98        1.98        0        0
#
#    UNITS
# 0     13
# 1     20
# 2     14
# 3     29
# 4     35

# %%
product_data.head()
# Out:
#           UPC               DESCRIPTION   MANUFACTURER               CATEGORY  \
# 0  1111009477    PL MINI TWIST PRETZELS  PRIVATE LABEL             BAG SNACKS
# 1  1111009497         PL PRETZEL STICKS  PRIVATE LABEL             BAG SNACKS
# 2  1111009507         PL TWIST PRETZELS  PRIVATE LABEL             BAG SNACKS
# 3  1111038078  PL BL MINT ANTSPTC RINSE  PRIVATE LABEL  ORAL HYGIENE PRODUCTS
# 4  1111038080  PL ANTSPTC SPG MNT MTHWS  PRIVATE LABEL  ORAL HYGIENE PRODUCTS
#
#                SUB_CATEGORY PRODUCT_SIZE
# 0                  PRETZELS        15 OZ
# 1                  PRETZELS        15 OZ
# 2                  PRETZELS        15 OZ
# 3  MOUTHWASHES (ANTISEPTIC)       500 ML
# 4  MOUTHWASHES (ANTISEPTIC)       500 ML

# %%
store_data.head()
# Out:
#    STORE_ID          STORE_NAME ADDRESS_CITY_NAME ADDRESS_STATE_PROV_CODE  \
# 0       367      15TH & MADISON         COVINGTON                      KY
# 1       389          SILVERLAKE          ERLANGER                      KY
# 2       613          EAST ALLEN             ALLEN                      TX
# 3       623             HOUSTON           HOUSTON                      TX
# 4      2277  ANDERSON TOWNE CTR        CINCINNATI                      OH
#
#    MSA_CODE SEG_VALUE_NAME  PARKING_SPACE_QTY  SALES_AREA_SIZE_NUM  \
# 0     17140          VALUE              196.0                24721
# 1     17140     MAINSTREAM              408.0                46073
# 2     19100     MAINSTREAM              464.0                64926
# 3     26420     MAINSTREAM                NaN                46930
# 4     17140        UPSCALE                NaN                81958
#
#    AVG_WEEKLY_BASKETS
# 0               12707
# 1               24767
# 2               29386
# 3               36741
# ...

# %%
# Plot the relationship between price and units sold
plt.scatter(train["PRICE"], train["UNITS"])
plt.xlabel("Price")
plt.ylabel("Units Sold")
plt.title("Relationship between Price and Units Sold")

# Display the plot
plt.show()

# %%
'''So my possible hypothesis is that the lower the price the highter the sales but obviously there are outliers such
as pizza boxes where people want to eat good food and it result them to buy expensive food. so if the product
is something like frozen food than people prefer expensive items else cheaper.
